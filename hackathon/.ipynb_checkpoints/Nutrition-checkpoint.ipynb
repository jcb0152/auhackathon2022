# %%
import pandas as pd 
import json

# %%
df = pd.read_csv("dataset/nutrients_csvfile.csv")
csv_dic = df.to_dict()

category_labels = set()

for k, v in csv_dic['Category'].items():
    category_labels.add(v)

category = {k: {} for k in category_labels}

for k in csv_dic.keys():
    if (k == 'Category'):
        break
    
    for cat in category_labels:
        category[cat][k] = []
        
    for i in csv_dic[k]:
        category[csv_dic['Category'][i]][k].append(csv_dic[k][i])
        
with open("nutrition_data.json", 'w') as f:
    json.dump(category, f)
# Out:
# {'Seeds and Nuts': {'Food': ['Almonds', 'roasted and salted', 'Brazil nuts', 'Cashews', 'coconut sweetened', 'Peanut butter', 'Peanut butter, natural', 'Peanuts', 'Pecans', 'Sesame seeds', 'Sunflower seeds', 'Walnuts'], 'Measure': ['1/2 cup', '1/2 cup', '1/2 cup', '1/2 cup', '1/2 cup', '1/3 cup', '1/3 cup', '1/3 cup', '1/2 cup', '1/2 cup', '1/2 cup', '1/2 cup'], 'Grams': ['70', '70', '70', '70', '50', '50', '50', '50', '52', '50', '50', '50'], 'Calories': ['425', '439', '457', '392', '274', '300', '284', '290', '343', '280', '280', '325'], 'Protein': ['13', '13', '10', '12', '1', '12', '13', '13', '5', '9', '12', '7'], 'Fat': ['38', '40', '47', '32', '20', '25', '24', '25', '35', '24', '26', '32'], 'Sat.Fat': ['28', '31', '31', '28', '19', '17', '10', '16', '25', '13', '7', '7'], 'Fiber': ['1.8', '1.8', '2', '0.9', '2', '0.9', '0.9', '1.2', '1.1', '3.1', '1.9', '1'], 'Carbs': ['13', '13', '7', '20', '26', '9', '8', '9', '7', '10', '10', '8']}, 'Fruits R-Z': {'Food': ['Raisins', 'Rasp
# ...
